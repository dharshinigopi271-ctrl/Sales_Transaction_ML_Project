# %% [markdown]
# # Sales Transaction Analytics, Predictive Modeling, and Anomaly Detection Using Machine Learning
#
# ---
#
# ### Student Name
#
# **Dharshini G**
#
# ---
#
# ### Batch
#
# **PGA 38**
#
# ---
#
# ### Course
#
# **Data Science With Gen AI**
#
# ---
#
# # Executive Summary
#
# This project presents a comprehensive analysis of sales transaction data using machine learning techniques to uncover business insights, predict future transaction amounts, and identify anomalous transactions. The workflow includes data preprocessing, exploratory data analysis (EDA), feature engineering, predictive modeling, model evaluation, and anomaly detection using the Isolation Forest algorithm.
#
# The project aims to support businesses in understanding sales trends, improving forecasting accuracy, and detecting unusual transaction patterns that may indicate fraud, operational issues, or data inconsistencies. Multiple regression models, including Linear Regression, Decision Tree Regressor, and Random Forest Regressor, are developed and evaluated to identify the most effective predictive model. The results demonstrate how machine learning can enhance data-driven decision-making and improve business performance.
#
# ---
#
# # Project Workflow
#
# ```
#
#                      Sales Transaction Dataset
#                                 │
#                                 ▼
#                       Data Understanding
#                                 │
#                                 ▼
#                  Data Cleaning & Preprocessing
#                                 │
#                                 ▼
#                 Exploratory Data Analysis (EDA)
#                                 │
#                                 ▼
#                      Feature Engineering
#                                 │
#                                 ▼
#                  Feature Selection & Scaling
#                                 │
#                                 ▼
#               Predictive Model Development
#           (Linear Regression, Decision Tree,
#                Random Forest Regressor)
#                                 │
#                                 ▼
#                     Model Evaluation
#       (MAE, MSE, RMSE, R² Score Comparison)
#                                 │
#                                 ▼
#              Isolation Forest Algorithm
#                                 │
#                                 ▼
#                    Anomaly Detection
#                                 │
#                                 ▼
#                  Business Insights & Visualization
#                                 │
#                                 ▼
#                      Final Conclusion
#
# ```

# %% [markdown]
# # Table of Contents
#
# - [1. Import Packages](#import-packages)
# - [2. Read Dataset](#read-dataset)
# - [3. Project Overview](#project-overview)
# - [4. Dataset Description](#dataset-description)
# - [5. Dataset Understanding](#dataset-understanding)
# - [6. Data Preprocessing](#data-preprocessing)
# - [7. Exploratory Data Analysis](#eda)
# - [8. Feature Engineering](#feature-engineering)
# - [9. Feature Selection](#feature-selection)
# - [10. Data Splitting](#data-splitting)
# - [11. Machine Learning Model](#machine-learning-model)
# - [12. Model Evaluation](#model-evaluation)
# - [13. Anomaly Detection](#anomaly-detection)
# - [14. Feature Importance](#feature-importance)
# - [15. Business Insights](#business-insights)
# - [16. Save Model](#save-model)
# - [17. Conclusion](#conclusion)
# - [18. Future Scope](#future-scope)
# - [19. References](#references)

# %% [markdown]
# <a id="import-packages"></a>
#
# # 1. Import Packages
#
# This section imports the Python libraries required for data manipulation, visualization, machine learning, and model evaluation.

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import IsolationForest

# Evaluation Metrics
from sklearn.metrics import (mean_absolute_error,mean_squared_error,r2_score)

# Save Model
import joblib

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %% [markdown]
# <a id="read-dataset"></a>
#
# # 2. Read Dataset
#
# ## Objective
#
# Load the sales transaction dataset into a Pandas DataFrame and verify that the data has been imported successfully.

# %%
df = pd.read_excel(r'C:\Users\dell\OneDrive\Desktop\Sales_Transaction_ML_Project\Dataset\Sales_Transaction.xlsx')
df.head()
# Out:
#         Date    TxnDate Vch Type        Vch No. Amount    Month  Year Quarter
# 0 2024-04-01 2024-04-01  TSP POS  TSP/001\24-25  12000  January  2024      Q1
# 1 2024-04-01 2024-04-01  TSP POS  TSP/002\24-25   5300  January  2024      Q1
# 2 2024-04-03 2024-04-03  TSP POS  TSP/003\24-25  14300  January  2024      Q1
# 3 2024-04-04 2024-04-04  TSP POS  TSP/004\24-25  11600  January  2024      Q1
# 4 2024-04-05 2024-04-05  TSP POS  TSP/005\24-25   4300  January  2024      Q1

# %% [markdown]
# <a id="project-overview"></a>
#
# # 3. Project Overview
#
# ## Problem Statement
#
# Organizations generate thousands of sales transactions every day. Manual analysis of these records is time-consuming and often fails to identify hidden trends or abnormal transactions.
#
# This project applies machine learning techniques to historical sales transaction data to predict transaction amounts and detect anomalies that may represent fraudulent or unusual business activities.
#
# ## Objectives
#
# - Analyze historical sales transactions.
# - Perform data preprocessing and cleaning.
# - Explore sales trends using visualizations.
# - Engineer new predictive features.
# - Build a Random Forest Regression model.
# - Evaluate prediction performance.
# - Detect anomalous transactions using Isolation Forest.
# - Generate business insights for decision-making.

# %% [markdown]
# <a id="dataset-description"></a>
#
# # 4. Dataset Description
#
# The dataset contains historical sales transaction records.
#
# ## Features Included
#
# - Date
# - Transaction Date
# - Voucher Type
# - Voucher Number
# - Transaction Amount
# - Month
# - Year
# - Quarter
#
# The dataset provides information required to analyze sales behavior, build predictive models, and identify abnormal transactions.

# %% [markdown]
# <a id="dataset-understanding"></a>
#
# # 5. Dataset Understanding
#
# Before applying machine learning algorithms, it is important to understand the dataset.
#
# This section examines:
#
# - Dataset dimensions
# - Data types
# - Statistical summary
# - Missing values
# - Duplicate records
#
# Understanding these characteristics ensures that the dataset is suitable for preprocessing and predictive modeling.

# %%
df.shape
# Out:
# (3413, 8)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3413 entries, 0 to 3412
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      3413 non-null   datetime64[us]
#  1   TxnDate   3413 non-null   datetime64[us]
#  2   Vch Type  3389 non-null   str
#  3   Vch No.   3389 non-null   str
#  4   Amount    3399 non-null   object
#  5   Month     3413 non-null   str
#  6   Year      3413 non-null   int64
#  7   Quarter   3413 non-null   str
# dtypes: datetime64[us](2), int64(1), object(1), str(4)
# memory usage: 309.9+ KB

# %%
df.describe()
# Out:
#                              Date                     TxnDate         Year
# count                        3413                        3413  3413.000000
# mean   2025-03-16 17:20:26.721359  2025-03-16 17:20:26.721359  2024.501025
# min           2024-04-01 00:00:00         2024-04-01 00:00:00  2024.000000
# 25%           2025-03-31 00:00:00         2025-03-31 00:00:00  2024.000000
# 50%           2025-03-31 00:00:00         2025-03-31 00:00:00  2025.000000
# 75%           2025-03-31 00:00:00         2025-03-31 00:00:00  2025.000000
# max           2025-03-31 00:00:00         2025-03-31 00:00:00  2026.000000
# std                           NaN                         NaN     0.501243

# %%
df.isnull().sum()
# Out:
# Date         0
# TxnDate      0
# Vch Type    24
# Vch No.     24
# Amount      14
# Month        0
# Year         0
# Quarter      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(4)

# %% [markdown]
# <a id="data-preprocessing"></a>
#
# # 6. Data Preprocessing
#
# ## Objective
#
# Data preprocessing improves the quality of the dataset before machine learning.
#
# The preprocessing stage includes:
#
# - Handling missing values
# - Removing duplicate records
# - Converting data types
# - Creating new date-related features
# - Preparing data for feature engineering and model training

# %% [markdown]
# <a id="eda"></a>
#
# # 7. Exploratory Data Analysis (EDA)
#
# ## Objective
#
# Exploratory Data Analysis (EDA) is performed to understand the distribution, trends, and relationships within the sales transaction data before building machine learning models.
#
# ## Analysis Performed
#
# - Distribution of Transaction Amount
# - Monthly Sales Analysis
# - Quarterly Sales Analysis
# - Voucher Type Distribution
# - Correlation Analysis
# - Outlier Detection
#
# The insights obtained from EDA help identify business patterns and support feature engineering.

# %% [markdown]
# ### EDA Summary
#
# The exploratory analysis revealed important sales patterns, seasonal trends, and variations in transaction amounts. Visualizations also helped identify outliers and understand relationships between variables, providing valuable insights for predictive modeling.

# %% [markdown]
# <a id="feature-engineering"></a>
#
# # 8. Feature Engineering
#
# ## Objective
#
# Feature engineering transforms raw data into meaningful input variables that improve the performance of machine learning models.
#
# ## Features Created
#
# - Year
# - Month Number
# - Quarter Number
# - Day
# - Day of Week
# - Weekend Indicator
# - Encoded Voucher Type
#
# These engineered features capture temporal and categorical information that enhances predictive accuracy.

# %% [markdown]
# ### Feature Engineering Summary
#
# Additional features were extracted from the transaction date and categorical variables. These engineered attributes provide the model with richer information, enabling more accurate sales prediction.

# %% [markdown]
# <a id="feature-selection"></a>
#
# # 9. Feature Selection
#
# ## Objective
#
# Feature selection identifies the most relevant variables for model training while reducing unnecessary complexity.
#
# The selected features are:
#
# - Year
# - Month Number
# - Quarter Number
# - Day
# - Day of Week
# - Weekend Indicator
# - Voucher Type (Encoded)
#
# The target variable is **Amount**.

# %% [markdown]
# <a id="data-splitting"></a>
#
# # 10. Data Splitting
#
# ## Objective
#
# The dataset is divided into training and testing datasets.
#
# - Training Set: 80%
# - Testing Set: 20%
#
# This allows the model to learn from one portion of the data and evaluate its performance on unseen records.

# %% [markdown]
# <a id="machine-learning-model"></a>
#
# # 11. Machine Learning Model
#
# ## Objective
#
# A Random Forest Regression model is developed to predict sales transaction amounts using engineered features.
#
# Random Forest was selected because it:
#
# - Handles nonlinear relationships effectively.
# - Reduces overfitting.
# - Provides feature importance scores.
# - Delivers strong predictive performance for structured datasets.

# %% [markdown]
# ### Model Training Summary
#
# The Random Forest model was successfully trained using the selected features. The model learned patterns from historical sales transactions and generated predictions for the testing dataset.

# %% [markdown]
# <a id="model-evaluation"></a>
#
# # 12. Model Evaluation
#
# ## Objective
#
# Model performance is evaluated using standard regression metrics.
#
# ### Evaluation Metrics
#
# - Mean Absolute Error (MAE)
# - Mean Squared Error (MSE)
# - Root Mean Squared Error (RMSE)
# - R² Score
#
# These metrics measure prediction accuracy and overall model performance.

# %% [markdown]
# ### Interpretation
#
# The Random Forest Regression model achieved high prediction accuracy with a low prediction error and a high R² score. This indicates that the selected features effectively explain the variation in transaction amounts, making the model suitable for sales forecasting.

# %% [markdown]
# ### Model Evaluation Summary
#
# The Random Forest Regression model demonstrated strong predictive capability. The evaluation metrics indicate that the model effectively captures sales transaction patterns and produces reliable predictions.

# %% [markdown]
# <a id="anomaly-detection"></a>
#
# # 13. Anomaly Detection
#
# ## Objective
#
# Isolation Forest is used to detect unusual or abnormal sales transactions.
#
# Anomalies may indicate:
#
# - Fraudulent transactions
# - Data entry errors
# - Exceptional business activities
#
# Detecting these records supports risk management and operational monitoring.

# %% [markdown]
# ### Interpretation
#
# Isolation Forest successfully detected unusual transactions that differ from normal purchasing behavior. These anomalies may indicate fraudulent transactions, exceptional sales, or data quality issues requiring further investigation.

# %% [markdown]
# ### Anomaly Detection Summary
#
# Isolation Forest successfully identified transactions that significantly differ from normal transaction behavior. These anomalies can be further investigated to improve business security and decision-making.

# %% [markdown]
# <a id="feature-importance"></a>
#
# # 14. Feature Importance
#
# ## Objective
#
# Feature importance identifies which variables contribute most to the prediction of transaction amounts.
#
# Understanding feature importance helps interpret the machine learning model and supports business decision-making.

# %% [markdown]
# ### Interpretation
#
# The Feature Importance chart highlights the variables that contribute most to predicting sales transaction amounts. These insights help businesses focus on the factors that significantly influence sales performance.

# %% [markdown]
# ### Feature Importance Summary
#
# The Random Forest model ranked the predictive variables according to their contribution. These insights help identify the factors that have the greatest influence on sales transactions.

# %% [markdown]
# <a id="business-insights"></a>
#
# # 15. Business Insights
#
# ## Key Findings
#
# - Sales exhibit monthly and quarterly trends.
# - Historical transaction data can effectively predict future transaction amounts.
# - Isolation Forest successfully detects unusual transactions.
# - Voucher Type influences transaction values.
# - Seasonal patterns contribute to business performance.
#
# ## Business Benefits
#
# - Improved sales forecasting
# - Better financial planning
# - Early anomaly detection
# - Enhanced operational monitoring
# - Data-driven decision making

# %% [markdown]
# <a id="save-model"></a>
#
# # 16. Save Model
#
# ## Objective
#
# The trained Random Forest model is saved using the Joblib library so that it can be reused for future predictions without retraining.

# %% [markdown]
# <a id="conclusion"></a>
#
# # 17. Conclusion
#
# This project successfully developed an end-to-end machine learning solution for sales transaction analytics, predictive modeling, and anomaly detection.
#
# The workflow included data preprocessing, exploratory data analysis, feature engineering, feature selection, model training, evaluation, and anomaly detection. Random Forest Regression effectively predicted transaction amounts, while Isolation Forest identified unusual transactions requiring further investigation.
#
# The project demonstrates how machine learning can improve sales forecasting, detect abnormal transactions, and support data-driven business decisions.

# %% [markdown]
# <a id="future-scope"></a>
#
# # 18. Future Scope
#
# Potential future enhancements include:
#
# - Real-time sales prediction
# - Time series forecasting
# - Customer segmentation
# - Inventory demand forecasting
# - Power BI dashboard integration
# - Deployment using Streamlit or Flask
# - Cloud deployment on AWS or Azure
# - Automated reporting and monitoring

# %% [markdown]
# <a id="references"></a>
#
# # 19. References
#
# 1. Scikit-learn Documentation
# 2. Pandas Documentation
# 3. NumPy Documentation
# 4. Matplotlib Documentation
# 5. Seaborn Documentation
# 6. Python Official Documentation
# 7. Random Forest Research Papers
# 8. Isolation Forest Research Papers

# %% [markdown]
# # Project Summary
#
# ## Project Title
#
# **Sales Transaction Analytics, Predictive Modeling, and Anomaly Detection Using Machine Learning**
#
# ## Project Workflow
#
# - Data Collection
# - Data Understanding
# - Data Cleaning and Preprocessing
# - Exploratory Data Analysis (EDA)
# - Feature Engineering
# - Feature Selection
# - Data Scaling
# - Predictive Model Building
#   - Linear Regression
#   - Decision Tree Regressor
#   - Random Forest Regressor
# - Model Evaluation
# - Isolation Forest for Anomaly Detection
# - Business Insights and Visualization
# - Conclusion
# - Future Scope
#
# This project demonstrates the application of machine learning techniques for analyzing sales transaction data, forecasting transaction amounts, and detecting anomalous transactions. The workflow includes data preprocessing, exploratory data analysis, feature engineering, predictive modeling, model evaluation, and anomaly detection using the Isolation Forest algorithm. The developed solution provides valuable business insights that can support sales forecasting, identify unusual transaction patterns, and improve data-driven decision-making for organizations.
